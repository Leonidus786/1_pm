# %% [markdown]
# ## Operators -- Operators are used to perform operations on variables and values.

# %% [markdown]
# 1. Aritmetic Operators
# 2. Assignment Operators
# 3. Comparison
# 4. Logical
# 5. Bitwise
# 6. Identity
# 7. Membership

# %%
# Arithmetic - Arithmetic operators are used with numeric values to perform common mathematical operations.- Addition, Subtraction, Mutiplication, Division, Floor Divison, Modulo , Exponentiation


a = 30

b = 3

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
a + b
# Out:
# 33

# %%
a - b
# Out:
# 27

# %%
a * b
# Out:
# 90

# %%
a / b
# Out:
# 10.0

# %%
a % b # Modulo -- Remainder
# Out:
# 0

# %%
a // b # Floor divison returns quotient without decimal
# Out:
# 10

# %%
77 / 3
# Out:
# 25.666666666666668

# %%
77 % 3
# Out:
# 2

# %%
77 // 3
# Out:
# 25

# %%
2 ** 4 ## 2 raised to the power 4
# Out:
# 16

# %%
2 // 3
# Out:
# 0

# %%
2 / 3
# Out:
# 0.6666666666666666

# %%
5 ** 3
# Out:
# 125

# %% [markdown]
# ## Comparison Operators == Comparison operators are used to compare two values.

# %%
print(a)
print(b)
# Out:
# 30
# 3

# %%
# ==	Equal

a == b
# Out:
# False

# %%
# != -- Not Equal to

b != a
# Out:
# True

# %%
# > -- greater than
a > b
# Out:
# True

# %%
# < -- smaller than

b < a
# Out:
# True

# %%
# >= Greater than equal to

a >= b
# Out:
# True

# %%
a => b
# Out:
#   Cell In[23], line 1
#     a => b
#        ^
# SyntaxError: invalid syntax

# %%
# <= 

b <= a
# Out:
# True

# %%
7+7*7/7-7
# Out:
# 7.0

# %% [markdown]
# ### Identity Operators -- Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location.

# %%
a = ["Apple", "Avocado"]

b = ["Apple", "Avocado"]

C = a

# %%
id(a)
# Out:
# 2696002619968

# %%
id(b)
# Out:
# 2696002923264

# %%
id(C)
# Out:
# 2696002619968

# %%
a is b
# Out:
# False

# %%
a is not b
# Out:
# True

# %%
a == b
# Out:
# True

# %%
C is a
# Out:
# True
